# %% [markdown]
# # Ellastichoney analysis
# ## Subtitle

# %%
# %matplotlib inline
import json
file_name = 'elastichoney_logs.json'

# %%
import pandas as pd
from pandas.io.json import json_normalize
file = open(file_name)
data = json.loads(file.read())
json_normalize(data)
# Out:
#                     @timestamp @version device  \
# 0     2015-03-21T11:39:23.975Z        1  Other
# 1     2015-03-21T11:39:24.761Z        1  Other
# 2     2015-03-21T04:09:27.131Z        1  Other
# 3     2015-03-21T04:29:06.119Z        1  Other
# 4     2015-03-21T04:09:09.857Z        1  Other
# 5     2015-03-21T02:41:16.703Z        1  Other
# 6     2015-03-21T04:38:06.460Z        1  Other
# 7     2015-03-21T11:39:22.543Z        1  Other
# 8     2015-03-21T00:35:00.559Z        1  Other
# 9     2015-03-21T11:40:35.749Z        1  Other
# 10    2015-03-21T11:39:45.722Z        1  Other
# 11    2015-03-21T11:39:32.719Z        1  Other
# 12    2015-03-21T11:40:31.793Z        1  Other
# 13    2015-03-21T11:40:40.351Z        1  Other
# 14    2015-03-21T11:39:32.318Z        1  Other
# 15    2015-03-21T11:40:37.025Z        1  Other
# 16    2015-03-21T11:39:41.970Z        1  Other
# 17    2015-03-21T11:40:41.836Z        1  Other
# 18    2015-03-21T11:41:16.037Z        1  Other
# 19    2015-03-21T11:41:17.603Z        1  Other
# 20    2015-03-21T11:40:50.765Z        1  Other
# 21    2015-03-21T11:40:57.438Z        1  Other
# 22    2015-03-21T11:41:04.218Z        1  Other
# 23    2015-03-21T11:41:12.515Z        1  Other
# 24    2015-03-21T11:40:52.109Z        1  Other
# 25    2015-03-21T11:40:56.077Z        1  Other
# 26    2015-03-21T11:41:14.740Z        1  Other
# 27    2015-03-21T12:27:24.030Z        1  Other
# 28    2015-03-21T12:27:25.201Z        1  Other
# 29    2015-03-21T12:27:20.738Z        1  Other
# ...                        ...      ...    ...
# 7778  2015-05-08T14:30:21.430Z        1  Other
# 7779  2015-05-09T12:36:55.160Z        1  Other
# 7780  2015-05-09T04:04:00.148Z        1  Other
# 7781  2015-05-09T05:52:07.265Z        1  Other
# 7782  2015-05-09T05:12:41.718Z        1  Other
# 7783  2015-05-09T05:50:59.996Z        1  Other
# 7784  2015-05-09T05:52:12.523Z        1  Other
# 7785  2015-05-09T05:52:17.780Z        1  Other
# 7786  2015-05-09T07:05:01.557Z        1  Other
# 7787  2015-05-09T03:59:45.890Z        1  Other
# 7788  2015-05-09T13:22:24.462Z        1  Other
# 7789  2015-05-10T01:12:02.683Z        1  Other
# 7790  2015-05-09T13:22:40.721Z        1  Other
# 7791  2015-05-09T13:23:04.162Z        1  Other
# 7792  2015-05-09T13:22:35.285Z        1  Other
# 7793  2015-05-10T01:12:18.444Z        1  Other
# 7794  2015-05-09T14:43:37.717Z        1  Other
# 7795  2015-05-10T01:12:01.052Z        1  Other
# 7796  2015-05-09T19:03:07.200Z        1  Other
# 7797  2015-05-10T13:13:42.215Z        1  Other
# 7798  2015-05-10T05:55:23.425Z        1  Other
# 7799  2015-05-10T13:13:59.293Z        1  Other
# 7800  2015-05-10T13:14:08.860Z        1  Other
# 7801  2015-05-10T13:13:47.621Z        1  Other
# 7802  2015-05-10T05:55:28.737Z        1  Other
# 7803  2015-05-10T05:55:19.427Z        1  Other
# 7804  2015-05-10T13:13:43.155Z        1  Other
# 7805  2015-05-10T13:13:40.318Z        1  Other
# 7806  2015-05-10T13:14:10.113Z        1  Other
# 7807  2015-05-10T13:14:14.725Z        1  Other
#
#                                                    form  geoip.area_code  \
# 0                                                  None              NaN
# 1                                                  None              NaN
# 2                                                  None              NaN
# 3                                                  None              NaN
# 4                                                  None              NaN
# 5                                                  None              NaN
# 6                                                  None              NaN
# 7                                                  None              NaN
# 8                                                  None              323
# 9                                                  None              NaN
# 10                                                 None              NaN
# 11                                                 None              NaN
# 12                                                 None              NaN
# 13                                                 None              NaN
# 14                                                 None              NaN
# 15                                                 None              NaN
# 16                                                 None              NaN
# 17                                                 None              NaN
# 18                                                 None              NaN
# 19                                                 None              NaN
# 20                                                 None              NaN
# 21                                                 None              NaN
# 22                                                 None              NaN
# 23                                                 None              NaN
# 24                                                 None              NaN
# 25                                                 None              NaN
# 26                                                 None              NaN
# 27                                                 None              NaN
# 28                                                 None              NaN
# 29                                                 None              NaN
# ...                                                 ...              ...
# 7778  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7779  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7780  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7781  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7782  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7783  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7784  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7785  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7786  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7787  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7788  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7789  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7790  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7791  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7792  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7793  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7794  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7795  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7796                                            pretty=              NaN
# 7797  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7798  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7799  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7800  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7801  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7802  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7803  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7804  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7805  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7806  source={"size":1,"query":{"filtered":{"query":...              NaN
# 7807  source={"size":1,"query":{"filtered":{"query":...              NaN
#
#      geoip.city_name geoip.continent_code geoip.country_code2  \
# 0            Nanjing                   AS                  CN
# 1            Nanjing                   AS                  CN
# 2            Wenzhou                   AS                  CN
# 3            Wenzhou                   AS                  CN
# 4            Wenzhou                   AS                  CN
# 5            Wenzhou                   AS                  CN
# 6            Wenzhou                   AS                  CN
# 7            Nanjing                   AS                  CN
# 8        Los Angeles                   NA                  US
# 9            Nanjing                   AS                  CN
# 10           Nanjing                   AS                  CN
# 11           Nanjing                   AS                  CN
# 12           Nanjing                   AS                  CN
# 13           Nanjing                   AS                  CN
# 14           Nanjing                   AS                  CN
# 15           Nanjing                   AS                  CN
# 16           Nanjing                   AS                  CN
# 17           Nanjing                   AS                  CN
# 18           Nanjing                   AS                  CN
# 19           Nanjing                   AS                  CN
# 20           Nanjing                   AS                  CN
# 21           Nanjing                   AS                  CN
# 22           Nanjing                   AS                  CN
# 23           Nanjing                   AS                  CN
# 24           Nanjing                   AS                  CN
# 25           Nanjing                   AS                  CN
# 26           Nanjing                   AS                  CN
# 27           Nanjing                   AS                  CN
# 28           Nanjing                   AS                  CN
# 29           Nanjing                   AS                  CN
# ...              ...                  ...                 ...
# 7778        Shenyang                   AS                  CN
# 7779        Shenyang                   AS                  CN
# 7780         Beijing                   AS                  CN
# 7781         Beijing                   AS                  CN
# 7782         Beijing                   AS                  CN
# 7783         Beijing                   AS                  CN
# 7784         Beijing                   AS                  CN
# 7785         Beijing                   AS                  CN
# 7786         Beijing                   AS                  CN
# 7787         Beijing                   AS                  CN
# 7788        Shenyang                   AS                  CN
# 7789         Nanjing                   AS                  CN
# 7790        Shenyang                   AS                  CN
# 7791        Shenyang                   AS                  CN
# 7792        Shenyang                   AS                  CN
# 7793         Nanjing                   AS                  CN
# 7794         Nanjing                   AS                  CN
# 7795         Nanjing                   AS                  CN
# 7796           Jinan                   AS                  CN
# 7797        Shenyang                   AS                  CN
# 7798        Shenyang                   AS                  CN
# 7799        Shenyang                   AS                  CN
# 7800        Shenyang                   AS                  CN
# 7801        Shenyang                   AS                  CN
# 7802        Shenyang                   AS                  CN
# 7803        Shenyang                   AS                  CN
# 7804        Shenyang                   AS                  CN
# 7805        Shenyang                   AS                  CN
# 7806        Shenyang                   AS                  CN
# 7807        Shenyang                   AS                  CN
#
#      geoip.country_code3 geoip.country_name  \
# 0                    CHN              China
# 1                    CHN              China
# 2                    CHN              China
# 3                    CHN              China
# 4                    CHN              China
# 5                    CHN              China
# 6                    CHN              China
# 7                    CHN              China
# 8                    USA      United States
# 9                    CHN              China
# 10                   CHN              China
# 11                   CHN              China
# 12                   CHN              China
# 13                   CHN              China
# 14                   CHN              China
# 15                   CHN              China
# 16                   CHN              China
# 17                   CHN              China
# 18                   CHN              China
# 19                   CHN              China
# 20                   CHN              China
# 21                   CHN              China
# 22                   CHN              China
# 23                   CHN              China
# 24                   CHN              China
# 25                   CHN              China
# 26                   CHN              China
# 27                   CHN              China
# 28                   CHN              China
# 29                   CHN              China
# ...                  ...                ...
# 7778                 CHN              China
# 7779                 CHN              China
# 7780                 CHN              China
# 7781                 CHN              China
# 7782                 CHN              China
# 7783                 CHN              China
# 7784                 CHN              China
# 7785                 CHN              China
# 7786                 CHN              China
# 7787                 CHN              China
# 7788                 CHN              China
# 7789                 CHN              China
# 7790                 CHN              China
# 7791                 CHN              China
# 7792                 CHN              China
# 7793                 CHN              China
# 7794                 CHN              China
# 7795                 CHN              China
# 7796                 CHN              China
# 7797                 CHN              China
# 7798                 CHN              China
# 7799                 CHN              China
# 7800                 CHN              China
# 7801                 CHN              China
# 7802                 CHN              China
# 7803                 CHN              China
# 7804                 CHN              China
# 7805                 CHN              China
# 7806                 CHN              China
# 7807                 CHN              China
#
#                             ...                                     name  \
# 0                           ...                          Python Requests
# 1                           ...                          Python Requests
# 2                           ...                                       IE
# 3                           ...                                       IE
# 4                           ...                                       IE
# 5                           ...                                       IE
# 6                           ...                                       IE
# 7                           ...                          Python Requests
# 8                           ...                                       IE
# 9                           ...                          Python Requests
# 10                          ...                          Python Requests
# 11                          ...                          Python Requests
# 12                          ...                          Python Requests
# 13                          ...                          Python Requests
# 14                          ...                          Python Requests
# 15                          ...                          Python Requests
# 16                          ...                          Python Requests
# 17                          ...                          Python Requests
# 18                          ...                          Python Requests
# 19                          ...                          Python Requests
# 20                          ...                          Python Requests
# 21                          ...                          Python Requests
# 22                          ...                          Python Requests
# 23                          ...                          Python Requests
# 24                          ...                          Python Requests
# 25                          ...                          Python Requests
# 26                          ...                          Python Requests
# 27                          ...                          Python Requests
# 28                          ...                          Python Requests
# 29                          ...                          Python Requests
# ...                         ...                                      ...
# 7778                        ...                                       IE
# 7779                        ...                                       IE
# 7780                        ...                                       IE
# 7781                        ...                                       IE
# 7782                        ...                                       IE
# 7783                        ...                                       IE
# 7784                        ...                                       IE
# 7785                        ...                                       IE
# 7786                        ...                                       IE
# 7787                        ...                                       IE
# 7788                        ...                                       IE
# 7789                        ...                                       IE
# 7790                        ...                                       IE
# 7791                        ...                                       IE
# 7792                        ...                                       IE
# 7793                        ...                                       IE
# 7794                        ...                                       IE
# 7795                        ...                                       IE
# 7796                        ...                                    Other
# 7797                        ...                                       IE
# 7798                        ...                                       IE
# 7799                        ...                                       IE
# 7800                        ...                                       IE
# 7801                        ...                                       IE
# 7802                        ...                                       IE
# 7803                        ...                                       IE
# 7804                        ...                                       IE
# 7805                        ...                                       IE
# 7806                        ...                                       IE
# 7807                        ...                                       IE
#
#                 os  os_major os_minor       os_name patch  \
# 0          Windows       NaN      NaN       Windows   NaN
# 1          Windows       NaN      NaN       Windows   NaN
# 2     Windows 2000       NaN      NaN  Windows 2000   NaN
# 3     Windows 2000       NaN      NaN  Windows 2000   NaN
# 4     Windows 2000       NaN      NaN  Windows 2000   NaN
# 5     Windows 2000       NaN      NaN  Windows 2000   NaN
# 6     Windows 2000       NaN      NaN  Windows 2000   NaN
# 7          Windows       NaN      NaN       Windows   NaN
# 8     Windows 2000       NaN      NaN  Windows 2000   NaN
# 9          Windows       NaN      NaN       Windows   NaN
# 10         Windows       NaN      NaN       Windows   NaN
# 11         Windows       NaN      NaN       Windows   NaN
# 12         Windows       NaN      NaN       Windows   NaN
# 13         Windows       NaN      NaN       Windows   NaN
# 14         Windows       NaN      NaN       Windows   NaN
# 15         Windows       NaN      NaN       Windows   NaN
# 16         Windows       NaN      NaN       Windows   NaN
# 17         Windows       NaN      NaN       Windows   NaN
# 18         Windows       NaN      NaN       Windows   NaN
# 19         Windows       NaN      NaN       Windows   NaN
# 20         Windows       NaN      NaN       Windows   NaN
# 21         Windows       NaN      NaN       Windows   NaN
# 22         Windows       NaN      NaN       Windows   NaN
# 23         Windows       NaN      NaN       Windows   NaN
# 24         Windows       NaN      NaN       Windows   NaN
# 25         Windows       NaN      NaN       Windows   NaN
# 26         Windows       NaN      NaN       Windows   NaN
# 27         Windows       NaN      NaN       Windows   NaN
# 28         Windows       NaN      NaN       Windows   NaN
# 29         Windows       NaN      NaN       Windows   NaN
# ...            ...       ...      ...           ...   ...
# 7778  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7779  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7780  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7781  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7782  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7783  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7784  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7785  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7786  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7787  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7788  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7789  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7790  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7791  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7792  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7793  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7794  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7795  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7796         Other       NaN      NaN         Other   NaN
# 7797  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7798  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7799  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7800  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7801  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7802  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7803  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7804  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7805  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7806  Windows 2000       NaN      NaN  Windows 2000   NaN
# 7807  Windows 2000       NaN      NaN  Windows 2000   NaN
#
#                                                 payload           source  \
# 0     source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 1     source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 2     source={"size":1,"query":{"filtered":{"query":...   115.234.254.53
# 3     source={"size":1,"query":{"filtered":{"query":...   115.234.254.53
# 4     source={"size":1,"query":{"filtered":{"query":...   115.234.254.53
# 5     source={"size":1,"query":{"filtered":{"query":...   115.234.254.53
# 6     source={"size":1,"query":{"filtered":{"query":...   115.234.254.53
# 7     source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 8     pretty=&{"size":1,"script_fields":+{"keyexp":+...  173.247.232.245
# 9     source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 10    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 11    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 12    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 13    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 14    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 15    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 16    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 17    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 18    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 19    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 20    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 21    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 22    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 23    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 24    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 25    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 26    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 27    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 28    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# 29    source={"query":+{"filtered":+{"query":+{"matc...     58.220.3.207
# ...                                                 ...              ...
# 7778                                                      61.176.220.162
# 7779                                                      61.176.220.162
# 7780                                                      120.24.170.212
# 7781                                                      120.24.170.212
# 7782                                                      120.24.170.212
# 7783                                                      120.24.170.212
# 7784                                                      120.24.170.212
# 7785                                                      120.24.170.212
# 7786                                                      120.24.170.212
# 7787                                                      120.24.170.212
# 7788                                                      61.176.220.162
# 7789                                                       222.186.34.70
# 7790                                                      61.176.220.162
# 7791                                                      61.176.220.162
# 7792                                                      61.176.220.162
# 7793                                                       222.186.34.70
# 7794                                                       222.186.34.70
# 7795                                                       222.186.34.70
# 7796  {"size":1,"script_fields": {"exp": {"script":"...   119.167.139.37
# 7797                                                      61.176.220.162
# 7798                                                       61.176.223.77
# 7799                                                      61.176.220.162
# 7800                                                      61.176.220.162
# 7801                                                      61.176.220.162
# 7802                                                       61.176.223.77
# 7803                                                       61.176.223.77
# 7804                                                      61.176.220.162
# 7805                                                      61.176.220.162
# 7806                                                      61.176.220.162
# 7807                                                      61.176.220.162
#
#         type                                                url
# 0     attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 1     attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 2     attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 3     attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 4     attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 5     attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 6     attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7     attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 8     attack                        x.x.x.x:9200/_search?pretty
# 9     attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 10    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 11    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 12    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 13    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 14    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 15    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 16    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 17    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 18    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 19    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 20    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 21    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 22    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 23    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 24    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 25    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 26    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 27    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 28    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# 29    attack  x.x.x.x:9200/_search?source=%7B%22query%22%3A+...
# ...      ...                                                ...
# 7778  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7779  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7780  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7781  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7782  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7783  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7784  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7785  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7786  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7787  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7788  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7789  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7790  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7791  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7792  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7793  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7794  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7795  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7796  attack                        x.x.x.x:9200/_search?pretty
# 7797  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7798  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7799  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7800  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7801  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7802  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7803  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7804  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7805  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7806  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
# 7807  attack  x.x.x.x:9200/_search?source=%7B%22size%22%3A1%...
#
# [7808 rows x 38 columns]

# %%
norm_data = json_normalize(data[:])
df = pandas.DataFrame(norm_data)
df.hist()
list(df.columns.values)
#norm_data
# Out:
# [u'@timestamp',
#  u'@version',
#  u'device',
#  u'form',
#  'geoip.area_code',
#  'geoip.city_name',
#  'geoip.continent_code',
#  'geoip.country_code2',
#  'geoip.country_code3',
#  'geoip.country_name',
#  'geoip.dma_code',
#  'geoip.ip',
#  'geoip.latitude',
#  'geoip.location',
#  'geoip.longitude',
#  'geoip.postal_code',
#  'geoip.real_region_name',
#  'geoip.region_name',
#  'geoip.timezone',
#  'headers.accept_language',
#  'headers.content_type',
#  'headers.host',
#  'headers.user_agent',
#  u'honeypot',
#  u'host',
#  u'major',
#  u'method',
#  u'minor',
#  u'name',
#  u'os',
#  u'os_major',
#  u'os_minor',
#  u'os_name',
#  u'patch',
#  u'payload',
#  u'source',
#  u'type',
#  u'url']

# %%
import vincent
vincent.core.initialize_notebook()
world_countries = city_names
geo_data = [{'name': 'countries',
             'url': 'https://github.com/wrobstory/vincent_map_data/blob/master/world-countries.topo.json',
             'feature': 'world-countries'}]
world = vincent.Map(geo_data=geo_data, scale=200)
world.display()
#world.geo_data(projection='winkel3', scale=200, world=world_countries)
#world.to_json(path)
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <div id="visf6bd11f1721a4aa986472342c6538041"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"format": {"feature": "world-countries", "type": "topojson"}, "name": "countries", "transform": [{"projection": "winkel3", "scale": 200, "translate": [480, 250], "type": "geopath", "value": "data"}], "url": "https://github.com/wrobstory/vincent_map_data/blob/master/world-countries.topo.json"}], "height": 500, "legends": [], "marks": [{"from": {"data": "countries"}, "properties": {"enter": {"path": {"field": "path"}, "stroke": {"value": "#000000"}}, "update": {"fill": {"value": "steelblue"}}}, "type": "path"}], "padding": "auto", "scales": [], "width": 960}, function(chart) {
#          chart({el: "#visf6bd11f1721a4aa986472342c6538041"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
